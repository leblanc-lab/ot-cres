# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#check number of cores and compile specter
num_cores = os.cpu_count()
print(f"Number of CPU cores: {num_cores}")
# Out:
# Number of CPU cores: 48

# %%
path = '/oscar/data/mleblan6/lhay/zjet_beta0p5/'

had_beta0p5_reweights = np.zeros((7, 100000))
had_beta0p5_radii = np.array([10,20,30,33,40,50,60])

for i in range(7):
    had_beta0p5_reweights[i] = np.load(f'{path}100k_had_emd_b0p5_reweight_{had_beta0p5_radii[i]}gev.npy')

for i in range(7):
    print(1 - len(had_beta0p5_reweights[i][had_beta0p5_reweights[i] < 0]) / 37581)
# Out:
# 0.0
# 0.0028737926079668297
# 0.14576514728187118
# 0.2531864506000373
# 0.48293020409249354
# 0.7014714882520423
# 0.8229158351294537

# %%
hp_beta2_radii = np.array([1.1,1.2,1.3,1.4,1.5,1.6,1.7])
path = '/oscar/data/mleblan6/lhay/zjet_beta2NEW/100k_hp_emd_b2RJ_reweight_'
hp_beta2_reweights = [np.load(f'{path}1p1gev.npy'), np.load(f'{path}1p2gev.npy'), np.load(f'{path}1p3gev.npy'), 
             np.load(f'{path}1p4gev.npy'), np.load(f'{path}1p5gev.npy'), np.load(f'{path}1p6gev.npy'), np.load(f'{path}1p7gev.npy')]


sho_beta2_radii = np.array([1,1.1,1.2,1.3,1.5,1.6,1.7,1.8])
path = '/oscar/data/mleblan6/lhay/zjet_beta2NEW/100k_ps_emd_b2NEW_reweight_'
sho_beta2_reweights = [np.load(f'{path}1p0gev.npy'), np.load(f'{path}1p1gev.npy'), np.load(f'{path}1p2gev.npy'), np.load(f'{path}1p3gev.npy'), 
             np.load(f'{path}1p5gev.npy'), np.load(f'{path}1p6gev.npy'), np.load(f'{path}1p7gev.npy'), 
np.load(f'{path}1p8gev.npy')]


had_beta2_radii = np.array([1,1.1,1.2,1.3,1.35,1.4,1.5,1.53,1.6])
path = '/oscar/data/mleblan6/lhay/zjet_beta2NEW/100k_had_emd_b2NEW_reweight_'
had_beta2_reweights = [np.load(f'{path}1p0gev.npy'),np.load(f'{path}1p1gev.npy'),np.load(f'{path}1p2gev.npy'),np.load(f'{path}1p3gev.npy'),
                       np.load(f'{path}1p35gev.npy'),np.load(f'{path}1p4gev.npy'),np.load(f'{path}1p5gev.npy'),np.load(f'{path}1p53gev.npy'),
np.load(f'{path}1p6gev.npy')]


# for i in range(7):
#     print(1 - len(hp_beta2_reweights[i][hp_beta2_reweights[i] < 0]) / 37581)

# print('--------------------')
# for i in range(8):
#     print(1 - len(sho_beta2_reweights[i][sho_beta2_reweights[i] < 0]) / 37581)
# print('--------------------')

# for i in range(9):
#     print(1 - len(had_beta2_reweights[i][had_beta2_reweights[i] < 0]) / 37581)

# %%
#rescaling factor for p1_semd to make it dimensionally consistant

pts = np.load('/oscar/data/mleblan6/rjain/ppzjj_100k/hardprocess_points.npy')[:,:,0]
max_hpht2 = np.max([pts[i].sum() for i in range(len(pts))])**2

pts = np.load('/oscar/data/mleblan6/rjain/ppzjj_100k/showered_points.npy')[:,:,0]
max_shoht2 = np.max([pts[i].sum() for i in range(len(pts))])**2

pts = np.load('/oscar/data/mleblan6/rjain/ppzjj_100k/hadronization_points.npy')[:,:,0]
max_hadht2 = np.max([pts[i].sum() for i in range(len(pts))])**2

# %%
weight = np.load('/oscar/data/mleblan6/rjain/ppzjj_100k/weight_100k.npy')

hp_radii = [5, 7, 9, 9.2, 9.5, 10, 12, 12.5, 12.9, 13.1, 15, 18, 20, 25]
sho_radii = [5, 9, 10, 12.5, 12.6, 15, 17.2, 20, 25]
had_radii = [5, 10, 13, 15, 17.2, 20, 25]

hp_beta0p5_radii = [10,20,30,40]
sho_beta0p5_radii = [25,30,40,50]

hp_semd_radii = np.logspace(1,np.log10(200),50)

betainf_radii = np.logspace(-4,-1,50)

beta0_radii = np.logspace(1.5,3,50)

hp_p1semd_radii = np.logspace(-5,-2,50) * max_hpht2
sho_p1semd_radii = np.logspace(-4,-2,50) * max_shoht2
had_p1semd_radii = np.logspace(-4,-2,50) * max_hadht2

path = '/oscar/data/mleblan6/rjain/100k_reweight_bigR/'

hp_reweights = [np.load(f'{path}100k_hp_emd_reweight_5gev_bigR.npy'), np.load(f'{path}100k_hp_emd_reweight_7gev_bigR.npy'),
                 np.load(f'{path}100k_hp_emd_reweight_9gev_bigR.npy'), np.load(f'{path}100k_hp_emd_reweight_9p2gev_bigR.npy'),
np.load(f'{path}100k_hp_emd_reweight_9p5gev_bigR.npy'), np.load(f'{path}100k_hp_emd_reweight_10gev_bigR.npy'), 
np.load(f'{path}100k_hp_emd_reweight_12gev_bigR.npy'), np.load(f'{path}100k_hp_emd_reweight_12p5gev_bigR.npy'), 
np.load(f'{path}100k_hp_emd_reweight_12p9gev_bigR.npy'), np.load(f'{path}100k_hp_emd_reweight_13p1gev_bigR.npy'),
np.load(f'{path}100k_hp_emd_reweight_15gev_bigR.npy'), np.load(f'{path}100k_hp_emd_reweight_18gev_bigR.npy'), 
np.load(f'{path}100k_hp_emd_reweight_20gev_bigR.npy'),np.load(f'{path}100k_hp_emd_reweight_25gev_bigR.npy')]

sho_reweights = [np.load(f'{path}100k_sho_emd_reweight_5gev_bigR.npy'), np.load(f'{path}100k_sho_emd_reweight_9gev_bigR.npy'),
                 np.load(f'{path}100k_sho_emd_reweight_10gev_bigR.npy'), np.load(f'{path}100k_sho_emd_reweight_12p5gev_bigR.npy'),
np.load(f'{path}100k_sho_emd_reweight_12p6gev_bigR.npy'), np.load(f'{path}100k_sho_emd_reweight_15gev_bigR.npy'), 
np.load(f'{path}100k_sho_emd_reweight_17p2gev_bigR.npy'), np.load(f'{path}100k_sho_emd_reweight_20gev_bigR.npy'), 
np.load(f'{path}100k_sho_emd_reweight_25gev_bigR.npy')]

had_reweights = [np.load(f'{path}100k_had_emd_reweight_5gev_bigR.npy'), np.load(f'{path}100k_had_emd_reweight_10gev_bigR.npy'),
                 np.load(f'{path}100k_had_emd_reweight_13gev_bigR.npy'), np.load(f'{path}100k_had_emd_reweight_15gev_bigR.npy'),
np.load(f'{path}100k_had_emd_reweight_17p2gev_bigR.npy'), np.load(f'{path}100k_had_emd_reweight_20gev_bigR.npy'), 
np.load(f'{path}100k_had_emd_reweight_25gev_bigR.npy')]

hp_beta0p5_reweights = [np.load(f'/oscar/data/mleblan6/jmarrinan/hp_reweights/100k_hp_emd_reweight_10gev_Rmax_beta0p5.npy'), 
                        np.load(f'/oscar/data/mleblan6/jmarrinan/hp_reweights/100k_hp_emd_reweight_20gev_Rmax_beta0p5.npy'), 
np.load(f'/oscar/data/mleblan6/jmarrinan/hp_reweights/100k_hp_emd_reweight_30gev_Rmax_beta0p5.npy'), 
                        np.load(f'/oscar/data/mleblan6/jmarrinan/hp_reweights/100k_hp_emd_reweight_40gev_Rmax_beta0p5.npy')]

sho_beta0p5_reweights = [np.load(f'/oscar/data/mleblan6/jmarrinan/sho_reweights/100k_shower_emd_reweight_25gev_Rmax_beta0p5.npy'), 
                         np.load(f'/oscar/data/mleblan6/jmarrinan/sho_reweights/100k_shower_emd_reweight_30gev_Rmax_beta0p5.npy'), 
np.load(f'/oscar/data/mleblan6/jmarrinan/sho_reweights/100k_shower_emd_reweight_40gev_Rmax_beta0p5.npy'), 
                         np.load(f'/oscar/data/mleblan6/jmarrinan/sho_reweights/100k_shower_emd_reweight_50gev_Rmax_beta0p5.npy')]

hp_semd_reweights = np.load('/oscar/data/mleblan6/rjain/semd_reweight/hardprocess_reweights.npy')

hp_betainf_reweights = np.load('/oscar/data/mleblan6/rjain/betainf/hardprocess_reweights.npy')
sho_betainf_reweights = np.load('/oscar/data/mleblan6/rjain/betainf/showered_reweights.npy')
had_betainf_reweights = np.load('/oscar/data/mleblan6/rjain/betainf/hadronization_reweights.npy')

hp_beta0_reweights = np.load('/oscar/data/mleblan6/rjain/beta0/hardprocess_reweights_fixed.npy')
sho_beta0_reweights = np.load('/oscar/data/mleblan6/rjain/beta0/showered_reweights_fixed.npy')
had_beta0_reweights = np.load('/oscar/data/mleblan6/rjain/beta0/hadronization_reweights_fixed.npy')

hp_p1semd_reweights = np.load('/oscar/data/mleblan6/rjain/p1_semd/hardprocess_reweights.npy')
sho_p1semd_reweights = np.load('/oscar/data/mleblan6/rjain/p1_semd/showered_reweights.npy')
had_p1semd_reweights = np.load('/oscar/data/mleblan6/rjain/p1_semd/hadronization_reweights.npy')

# %%
path = '/oscar/data/mleblan6/rjain/hundredK_XMD/'

hp_xmd_dist = np.load(f'{path}hp_XMD_v3.npy')
sho_xmd_dist = np.load(f'{path}sho_XMD_v3.npy')
had_xmd_dist = np.load(f'{path}had_XMD_v3.npy')
hp_beta0p5_xmd_dist = np.load(f'{path}hp_beta0p5_XMD.npy')
sho_beta0p5_xmd_dist = np.load(f'{path}sho_beta0p5_XMD.npy')
had_beta0p5_xmd_dist = np.load(f'{path}had_beta0p5_XMD.npy')
hp_semd_xmd_dist = np.load(f'{path}hp_semd_XMD.npy')
hp_betainf_xmd_dist = np.load(f'{path}hp_betainf_XMD.npy')
sho_betainf_xmd_dist = np.load(f'{path}sho_betainf_XMD.npy')
had_betainf_xmd_dist = np.load(f'{path}had_betainf_XMD.npy')
hp_p1semd_xmd_dist = np.load(f'{path}hp_p1_semd_XMD.npy')
sho_p1semd_xmd_dist = np.load(f'{path}sho_p1_semd_XMD.npy')
had_p1semd_xmd_dist = np.load(f'{path}had_p1_semd_XMD.npy')
hp_beta0_xmd_dist = np.load(f'{path}hp_beta0_XMD.npy')
sho_beta0_xmd_dist = np.load(f'{path}sho_beta0_XMD.npy')
had_beta0_xmd_dist = np.load(f'{path}had_beta0_XMD.npy')
had_beta2_xmd_dist = np.load(f'{path}had_beta2_XMD.npy')[0:9] #only take subset bc XMD convergence issues
sho_beta2_xmd_dist = np.load(f'{path}sho_beta2_XMD.npy')[0:8] #only take subset bc XMD convergence issues
hp_beta2_xmd_dist = np.load(f'{path}hp_beta2_XMD.npy')

hp_neg_percent = [1 - len(hp_reweights[i][hp_reweights[i]<0])/len(weight[weight<0]) for i in range(len(hp_reweights))]
sho_neg_percent = [1 - len(sho_reweights[i][sho_reweights[i]<0])/len(weight[weight<0]) for i in range(len(sho_reweights))]
had_neg_percent = [1 - len(had_reweights[i][had_reweights[i]<0])/len(weight[weight<0]) for i in range(len(had_reweights))]

hp_beta0p5_neg_percent = [1 - len(hp_beta0p5_reweights[i][hp_beta0p5_reweights[i]<0])/len(weight[weight<0]) for i in range(len(hp_beta0p5_reweights))]
sho_beta0p5_neg_percent = [1 - len(sho_beta0p5_reweights[i][sho_beta0p5_reweights[i]<0])/len(weight[weight<0]) for i in range(len(sho_beta0p5_reweights))]
had_beta0p5_neg_percent = [1 - len(had_beta0p5_reweights[i][had_beta0p5_reweights[i]<0])/len(weight[weight<0]) for i in range(len(had_beta0p5_reweights))]


hp_semd_neg_percent = [1 - len(hp_semd_reweights[i][hp_semd_reweights[i]<0])/len(weight[weight<0]) for i in range(len(hp_semd_reweights))]

hp_betainf_neg_percent = [1 - len(hp_betainf_reweights[i][hp_betainf_reweights[i]<0])/len(weight[weight<0]) for i in range(len(hp_betainf_reweights))]
sho_betainf_neg_percent = [1 - len(sho_betainf_reweights[i][sho_betainf_reweights[i]<0])/len(weight[weight<0]) for i in range(len(sho_betainf_reweights))]
had_betainf_neg_percent = [1 - len(had_betainf_reweights[i][had_betainf_reweights[i]<0])/len(weight[weight<0]) for i in range(len(had_betainf_reweights))]

hp_beta0_neg_percent = [1 - len(hp_beta0_reweights[i][hp_beta0_reweights[i]<0])/len(weight[weight<0]) for i in range(len(hp_beta0_reweights))]
sho_beta0_neg_percent = [1 - len(sho_beta0_reweights[i][sho_beta0_reweights[i]<0])/len(weight[weight<0]) for i in range(len(sho_beta0_reweights))]
had_beta0_neg_percent = [1 - len(had_beta0_reweights[i][had_beta0_reweights[i]<0])/len(weight[weight<0]) for i in range(len(had_beta0_reweights))]

hp_p1semd_neg_percent = [1 - len(hp_p1semd_reweights[i][hp_p1semd_reweights[i]<0])/len(weight[weight<0]) for i in range(len(hp_p1semd_reweights))]
sho_p1semd_neg_percent = [1 - len(sho_p1semd_reweights[i][sho_p1semd_reweights[i]<0])/len(weight[weight<0]) for i in range(len(sho_p1semd_reweights))]
had_p1semd_neg_percent = [1 - len(had_p1semd_reweights[i][had_p1semd_reweights[i]<0])/len(weight[weight<0]) for i in range(len(had_p1semd_reweights))]

hp_beta2_neg_percent = [1 - len(hp_beta2_reweights[i][hp_beta2_reweights[i]<0])/len(weight[weight<0]) for i in range(len(hp_beta2_reweights))]
sho_beta2_neg_percent = [1 - len(sho_beta2_reweights[i][sho_beta2_reweights[i]<0])/len(weight[weight<0]) for i in range(len(sho_beta2_reweights))]
had_beta2_neg_percent = [1 - len(had_beta2_reweights[i][had_beta2_reweights[i]<0])/len(weight[weight<0]) for i in range(len(had_beta2_reweights))]

# %%
plt.figure(figsize=(8, 6))

plt.axhline(weight.sum()/np.sqrt(len(weight)), color = 'black', label = 'XS Error')
plt.plot(hp_neg_percent, hp_xmd_dist, color = 'red', marker = 'o', label = 'Hard Process β = 1 EMD', linestyle = '--')
plt.plot(sho_neg_percent, sho_xmd_dist, color = 'blue', marker = 'o', label = 'Showered β = 1 EMD', linestyle = '--')
plt.plot(had_neg_percent, had_xmd_dist, color = 'orange', marker = 'o', label = 'Hadronization β = 1 EMD', linestyle = '--')
plt.plot(hp_beta0p5_neg_percent, hp_beta0p5_xmd_dist, color = 'green', marker = 's', label = 'Hard Process β = 0.5 EMD', linestyle = '--')
plt.plot(sho_beta0p5_neg_percent, sho_beta0p5_xmd_dist, color = 'magenta', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')
plt.plot(had_beta0p5_neg_percent, had_beta0p5_xmd_dist, color = 'lightsalmon', marker = 's', label = 'Hadronization β = 0.5 EMD', linestyle = '--')
plt.plot(hp_beta2_neg_percent, hp_beta2_xmd_dist, color = 'mediumslateblue', marker = '+', label = 'Hard Process β = 2 EMD', linestyle = '--')
plt.plot(sho_beta2_neg_percent, sho_beta2_xmd_dist, color = 'plum', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')
plt.plot(had_beta2_neg_percent, had_beta2_xmd_dist, color = 'midnightblue', marker = '+', label = 'Hadronization β = 2 EMD', linestyle = '--')
plt.plot(hp_betainf_neg_percent, hp_betainf_xmd_dist, color = 'purple', marker = 'x', label = 'Hard Process β = ∞ EMD', linestyle = '--')
plt.plot(sho_betainf_neg_percent, sho_betainf_xmd_dist, color = 'brown', marker = 'x', label = 'Showered β = ∞ EMD', linestyle = '--')
plt.plot(had_betainf_neg_percent, had_betainf_xmd_dist, color = 'pink', marker = 'x', label = 'Hadronization β = ∞ EMD', linestyle = '--')
plt.plot(hp_beta0_neg_percent[0:26], hp_beta0_xmd_dist, color = 'lime', marker = '*', label = 'Hard Process β = 0 EMD', linestyle = '--')
plt.plot(sho_beta0_neg_percent[0:29], sho_beta0_xmd_dist, color = 'mediumturquoise', marker = '*', label = 'Showered β = 0 EMD', linestyle = '--')
plt.plot(had_beta0_neg_percent[0:30], had_beta0_xmd_dist, color = 'mediumpurple', marker = '*', label = 'Hadronization β = 0 EMD', linestyle = '--')
plt.plot(hp_p1semd_neg_percent, hp_p1semd_xmd_dist, color = 'burlywood', marker = 'd', label = 'Hard Process p = 1 SEMD', linestyle = '--')
plt.plot(sho_p1semd_neg_percent, sho_p1semd_xmd_dist, color = 'olive', marker = 'd', label = 'Showered p = 1 SEMD', linestyle = '--')
plt.plot(had_p1semd_neg_percent, had_p1semd_xmd_dist, color = 'turquoise', marker = 'd', label = 'Hadronization p = 1 SEMD', linestyle = '--')
plt.plot(hp_semd_neg_percent, hp_semd_xmd_dist, color = 'cyan', marker = 'v', label = 'Hard Process p = 2 SEMD', linestyle = '--')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize = 12)
plt.xlabel('Reweighted Fraction', fontsize = 14)
plt.ylabel('XMD [pb]', fontsize = 14);
plt.ylim([0,275]);
#plt.savefig('all_xmd_updated.png', bbox_inches='tight')

# %%
plt.axhline(weight.sum()/np.sqrt(len(weight)), color = 'black', label = 'XS Error')
plt.plot(hp_beta0_neg_percent[0:26], hp_beta0_xmd_dist, color = 'lime', marker = '*', label = 'Hard Process β = 0 EMD', linestyle = '--')
plt.plot(hp_beta0p5_neg_percent, hp_beta0p5_xmd_dist, color = 'green', marker = 's', label = 'Hard Process β = 0.5 EMD', linestyle = '--')
plt.plot(hp_neg_percent, hp_xmd_dist, color = 'red', marker = 'o', label = 'Hard Process β = 1 EMD', linestyle = '--')
plt.plot(hp_beta2_neg_percent, hp_beta2_xmd_dist, color = 'mediumslateblue', marker = '+', label = 'Hard Process β = 2 EMD', linestyle = '--')
plt.plot(hp_betainf_neg_percent, hp_betainf_xmd_dist, color = 'purple', marker = 'x', label = 'Hard Process β = ∞ EMD', linestyle = '--')
plt.plot(hp_p1semd_neg_percent, hp_p1semd_xmd_dist, color = 'burlywood', marker = 'd', label = 'Hard Process p = 1 SEMD', linestyle = '--')
plt.plot(hp_semd_neg_percent, hp_semd_xmd_dist, color = 'cyan', marker = 'v', label = 'Hard Process p = 2 SEMD', linestyle = '--')


plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize = 14)
plt.xlabel('Reweighted Fraction', fontsize = 14)
plt.ylabel('XMD [pb]', fontsize = 14)
plt.ylim([0,275]);
#plt.savefig('hp_xmd_updated.png', bbox_inches='tight')

# %%
plt.axhline(weight.sum()/np.sqrt(len(weight)), color = 'black', label = 'XS Error')
plt.plot(sho_beta0_neg_percent[0:29], sho_beta0_xmd_dist, color = 'mediumturquoise', marker = '*', label = 'Showered β = 0 EMD', linestyle = '--')
plt.plot(sho_beta0p5_neg_percent, sho_beta0p5_xmd_dist, color = 'magenta', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')
plt.plot(sho_neg_percent, sho_xmd_dist, color = 'blue', marker = 'o', label = 'Showered β = 1 EMD', linestyle = '--')
plt.plot(sho_beta2_neg_percent, sho_beta2_xmd_dist, color = 'plum', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')
plt.plot(sho_betainf_neg_percent, sho_betainf_xmd_dist, color = 'brown', marker = 'x', label = 'Showered β = ∞ EMD', linestyle = '--')
plt.plot(sho_p1semd_neg_percent, sho_p1semd_xmd_dist, color = 'olive', marker = 'd', label = 'Showered p = 1 SEMD', linestyle = '--')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize = 14)
plt.xlabel('Reweighted Fraction', fontsize = 14)
plt.ylabel('XMD [pb]', fontsize = 14);
plt.ylim([0,275]);
plt.savefig('sho_xmd_updated.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8, 6))
plt.axhline(weight.sum()/np.sqrt(len(weight)), color = 'black', label = 'XS Error')
plt.plot(had_beta0_neg_percent[0:30], had_beta0_xmd_dist, color = 'mediumpurple', marker = '*', label = 'Hadronization β = 0 EMD', linestyle = '--')
plt.plot(had_beta0p5_neg_percent, had_beta0p5_xmd_dist, color = 'lightsalmon', marker = 's', label = 'Hadronization β = 0.5 EMD', linestyle = '--')
plt.plot(had_neg_percent, had_xmd_dist, color = 'orange', marker = 'o', label = 'Hadronization β = 1 EMD', linestyle = '--')
plt.plot(had_beta2_neg_percent, had_beta2_xmd_dist, color = 'midnightblue', marker = '+', label = 'Hadronization β = 2 EMD', linestyle = '--')
plt.plot(had_betainf_neg_percent, had_betainf_xmd_dist, color = 'pink', marker = 'x', label = 'Hadronization β = ∞ EMD', linestyle = '--')
plt.plot(had_p1semd_neg_percent, had_p1semd_xmd_dist, color = 'turquoise', marker = 'd', label = 'Hadronization p = 1 SEMD', linestyle = '--')


plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize = 14)
plt.xlabel('Reweighted Fraction', fontsize = 14)
plt.ylabel('XMD [pb]', fontsize = 14);
plt.savefig('had_xmd_updated.png', bbox_inches='tight')

# %%
plt.axhline(weight.sum()/np.sqrt(len(weight)), color = 'black', label = 'XS Error')
plt.plot(hp_beta0_neg_percent[0:26], hp_beta0_xmd_dist, color = 'lime', marker = '*', label = 'Hard Process β = 0', linestyle = '--')
plt.plot(sho_beta0_neg_percent[0:29], sho_beta0_xmd_dist, color = 'mediumturquoise', marker = '*', label = 'Showered β = 0', linestyle = '--')
plt.plot(had_beta0_neg_percent[0:30], had_beta0_xmd_dist, color = 'mediumpurple', marker = '*', label = 'Hadronization β = 0', linestyle = '--')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('Reweighted Fraction')
plt.ylabel('XMD [pb]')
plt.ylim([0,275]);
plt.xlim([0,1.02])
# Out:
# (0.0, 1.02)

# %%
plt.figure(figsize=(9, 6))
plt.axhline(1, color = 'black', label = '100% Reweighted')
plt.plot(hp_radii, hp_neg_percent, color = 'red', marker = 'o', label = 'Hard Process β = 1 EMD', linestyle = '--')
plt.plot(sho_radii, sho_neg_percent, color = 'blue', marker = 'o', label = 'Showered β = 1 EMD', linestyle = '--')
plt.plot(had_radii, had_neg_percent, color = 'orange', marker = 'o', label = 'Hadronization β = 1 EMD', linestyle = '--')
plt.plot(hp_beta0p5_radii, hp_beta0p5_neg_percent, color = 'green', marker = 's', label = 'Hard Process β = 0.5 EMD', linestyle = '--')
plt.plot(sho_beta0p5_radii, sho_beta0p5_neg_percent, color = 'magenta', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')
plt.plot(had_beta0p5_radii, had_beta0p5_neg_percent, color = 'lightsalmon', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')
plt.plot(hp_beta2_radii, hp_beta2_neg_percent, color = 'mediumslateblue', marker = '+', label = 'Hard Process β = 2 EMD', linestyle = '--')
plt.plot(sho_beta2_radii, sho_beta2_neg_percent, color = 'plum', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')
plt.plot(had_beta2_radii, had_beta2_neg_percent, color = 'midnightblue', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')
plt.plot(betainf_radii, hp_betainf_neg_percent, color = 'purple', marker = 'x', label = 'Hard Process β = ∞ EMD', linestyle = '--')
plt.plot(betainf_radii, sho_betainf_neg_percent, color = 'brown', marker = 'x', label = 'Showered β = ∞ EMD', linestyle = '--')
plt.plot(betainf_radii, had_betainf_neg_percent, color = 'pink', marker = 'x', label = 'Hadronization β = ∞ EMD', linestyle = '--')
plt.plot(beta0_radii, hp_beta0_neg_percent, color = 'lime', marker = '*', label = 'Hard Process β = 0 EMD', linestyle = '--')
plt.plot(beta0_radii, sho_beta0_neg_percent, color = 'mediumturquoise', marker = '*', label = 'Showered β = 0 EMD', linestyle = '--')
plt.plot(beta0_radii, had_beta0_neg_percent, color = 'mediumpurple', marker = '*', label = 'Hadronization β = 0 EMD', linestyle = '--')
plt.plot(hp_p1semd_radii, hp_p1semd_neg_percent, color = 'burlywood', marker = 'd', label = 'Hard Process p = 1 SEMD', linestyle = '--')
plt.plot(sho_p1semd_radii, sho_p1semd_neg_percent, color = 'olive', marker = 'd', label = 'Showered p = 1 SEMD', linestyle = '--')
plt.plot(had_p1semd_radii, had_p1semd_neg_percent, color = 'turquoise', marker = 'd', label = 'Hadronization p = 1 SEMD', linestyle = '--')
plt.plot(hp_semd_radii, hp_semd_neg_percent, color = 'cyan', marker = 'v', label = 'Hard Process p = 2 SEMD', linestyle = '--')

plt.xscale('log')
plt.ylim([0,1.05])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize = 12)
plt.xlabel('Cell Radius [GeV]', fontsize = 14)
plt.ylabel('Reweighted Fraction', fontsize = 14)
plt.savefig('reweight_frac.png', bbox_inches='tight')

# %%
hp_means = [np.mean(i/14550) for i in hp_reweights]
hp2_means = [np.mean((i/14550)**2) for i in hp_reweights]
hp_var = [np.var(i/14550) for i in hp_reweights]

sho_means = [np.mean(i/14550) for i in sho_reweights]
sho2_means = [np.mean((i/14550)**2) for i in sho_reweights]
sho_var = [np.var(i/14550) for i in sho_reweights]

had_means = [np.mean(i/14550) for i in had_reweights]
had2_means = [np.mean((i/14550)**2) for i in had_reweights]
had_var = [np.var(i/14550) for i in had_reweights]

hp_beta0p5_means = [np.mean(i/14550) for i in hp_beta0p5_reweights]
hp2_beta0p5_means = [np.mean((i/14550)**2) for i in hp_beta0p5_reweights]
hp_beta0p5_var = [np.var(i/14550) for i in hp_beta0p5_reweights]

sho_beta0p5_means = [np.mean(i/14550) for i in sho_beta0p5_reweights]
sho2_beta0p5_means = [np.mean((i/14550)**2) for i in sho_beta0p5_reweights]
sho_beta0p5_var = [np.var(i/14550) for i in sho_beta0p5_reweights]

had_beta0p5_means = [np.mean(i/14550) for i in had_beta0p5_reweights]
had2_beta0p5_means = [np.mean((i/14550)**2) for i in had_beta0p5_reweights]
had_beta0p5_var = [np.var(i) for i in had_beta0p5_reweights]

hp_beta2_means = [np.mean(i) for i in hp_beta2_reweights]
hp2_beta2_means = [np.mean((i)**2) for i in hp_beta2_reweights]
hp_beta2_var = [np.var(i) for i in hp_beta2_reweights]

sho_beta2_means = [np.mean(i) for i in sho_beta2_reweights]
sho2_beta2_means = [np.mean((i)**2) for i in sho_beta2_reweights]
sho_beta2_var = [np.var(i) for i in sho_beta2_reweights]

had_beta2_means = [np.mean(i) for i in had_beta2_reweights]
had2_beta2_means = [np.mean((i)**2) for i in had_beta2_reweights]
had_beta2_var = [np.var(i) for i in had_beta2_reweights]

hp_beta0_means = [np.mean(i) for i in hp_beta0_reweights]
hp2_beta0_means = [np.mean(i**2) for i in hp_beta0_reweights]
hp_beta0_var = [np.var(i) for i in hp_beta0_reweights]

sho_beta0_means = [np.mean(i) for i in sho_beta0_reweights]
sho2_beta0_means = [np.mean(i**2) for i in sho_beta0_reweights]
sho_beta0_var = [np.var(i) for i in sho_beta0_reweights]

had_beta0_means = [np.mean(i) for i in had_beta0_reweights]
had2_beta0_means = [np.mean(i**2) for i in had_beta0_reweights]
had_beta0_var = [np.var(i) for i in had_beta0_reweights]

hp_betainf_means = [np.mean(i) for i in hp_betainf_reweights]
hp2_betainf_means = [np.mean(i**2) for i in hp_betainf_reweights]
hp_betainf_var = [np.var(i) for i in hp_betainf_reweights]

sho_betainf_means = [np.mean(i) for i in sho_betainf_reweights]
sho2_betainf_means = [np.mean(i**2) for i in sho_betainf_reweights]
sho_betainf_var = [np.var(i) for i in sho_betainf_reweights]

had_betainf_means = [np.mean(i) for i in had_betainf_reweights]
had2_betainf_means = [np.mean(i**2) for i in had_betainf_reweights]
had_betainf_var = [np.var(i) for i in had_betainf_reweights]

hp_p1semd_means = [np.mean(i) for i in hp_p1semd_reweights]
hp2_p1semd_means = [np.mean(i**2) for i in hp_p1semd_reweights]
hp_p1semd_var = [np.var(i) for i in hp_p1semd_reweights]

sho_p1semd_means = [np.mean(i) for i in sho_p1semd_reweights]
sho2_p1semd_means = [np.mean(i**2) for i in sho_p1semd_reweights]
sho_p1semd_var = [np.var(i) for i in sho_p1semd_reweights]

had_p1semd_means = [np.mean(i) for i in had_p1semd_reweights]
had2_p1semd_means = [np.mean(i**2) for i in had_p1semd_reweights]
had_p1semd_var = [np.var(i) for i in had_p1semd_reweights]

hp_semd_means = [np.mean(i) for i in hp_semd_reweights]
hp2_semd_means = [np.mean(i**2) for i in hp_semd_reweights]
hp_semd_var = [np.var(i) for i in hp_semd_reweights]

orig_mean = np.mean(weight)
orig2_mean = np.mean(weight**2)
orig_var = np.var(weight)

# %%
plt.plot(hp_neg_percent, hp_var / orig_var, color = 'red', marker = 'o', label = 'Hard Process β = 1 EMD', linestyle = '--')
plt.plot(sho_neg_percent, sho_var / orig_var, color = 'blue', marker = 'o', label = 'Showered β = 1 EMD', linestyle = '--')
plt.plot(had_neg_percent, had_var / orig_var, color = 'orange', marker = 'o', label = 'Hadronization β = 1 EMD', linestyle = '--')

plt.plot(hp_beta0p5_neg_percent, hp_beta0p5_var / orig_var, color = 'green', marker = 's', label = 'Hard Process β = 0.5 EMD', linestyle = '--')
plt.plot(sho_beta0p5_neg_percent, sho_beta0p5_var / orig_var, color = 'magenta', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')
plt.plot(had_beta0p5_neg_percent, had_beta0p5_var / orig_var, color = 'lightsalmon', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')

plt.plot(hp_beta2_neg_percent, hp_beta2_var / orig_var, color = 'mediumslateblue', marker = '+', label = 'Hard Process β = 2 EMD', linestyle = '--')
plt.plot(sho_beta2_neg_percent, sho_beta2_var / orig_var, color = 'plum', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')
plt.plot(had_beta2_neg_percent, had_beta2_var / orig_var, color = 'midnightblue', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')

plt.plot(hp_beta0_neg_percent, hp_beta0_var / orig_var, color = 'lime', marker = '*', label = 'Hard Process β = 0 EMD', linestyle = '--')
plt.plot(sho_beta0_neg_percent, sho_beta0_var / orig_var, color = 'mediumturquoise', marker = '*', label = 'Showered β = 0 EMD', linestyle = '--')
plt.plot(had_beta0_neg_percent, had_beta0_var / orig_var, color = 'mediumpurple', marker = '*', label = 'Hadronization β = 0 EMD', linestyle = '--')

plt.plot(hp_betainf_neg_percent, hp_betainf_var / orig_var, color = 'purple', marker = 'x', label = 'Hard Process β = ∞ EMD', linestyle = '--')
plt.plot(sho_betainf_neg_percent, sho_betainf_var / orig_var, color = 'brown', marker = 'x', label = 'Showered β = ∞ EMD', linestyle = '--')
plt.plot(had_betainf_neg_percent, had_betainf_var / orig_var, color = 'pink', marker = 'x', label = 'Hadronization β = ∞ EMD', linestyle = '--')

plt.plot(hp_p1semd_neg_percent, hp_p1semd_var / orig_var, color = 'burlywood', marker = 'd', label = 'Hard Process p = 1 SEMD', linestyle = '--')
plt.plot(sho_p1semd_neg_percent, sho_p1semd_var / orig_var, color = 'olive', marker = 'd', label = 'Showered p = 1 SEMD', linestyle = '--')
plt.plot(had_p1semd_neg_percent, had_p1semd_var / orig_var, color = 'turquoise', marker = 'd', label = 'Hadronization p = 1 SEMD', linestyle = '--')

plt.plot(hp_semd_neg_percent, hp_semd_var / orig_var, color = 'cyan', marker = 'v', label = 'Hard Process p = 2 SEMD', linestyle = '--')

plt.axhline(0, color = 'black', linestyle = '--', label = 'Fully positive, uniform sample')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('Reweighted Fraction')
plt.ylabel('Variance of Weights wrt Original Variance')
plt.savefig('variance.png', bbox_inches='tight')

# %%
plt.figure(figsize=(8, 6))

plt.axvline(0.2, color = 'gray', linestyle = '--')
plt.axvline(0.4, color = 'gray', linestyle = '--')
plt.axvline(0.6, color = 'gray', linestyle = '--')
plt.axvline(0.8, color = 'gray', linestyle = '--')

plt.plot(hp_neg_percent, 1 / (np.array(hp_means)**2 / hp2_means), color = 'red', marker = 'o', label = 'Hard Process β = 1 EMD', linestyle = '--')
plt.plot(sho_neg_percent, 1 / (np.array(sho_means)**2 / sho2_means), color = 'blue', marker = 'o', label = 'Showered β = 1 EMD', linestyle = '--')
plt.plot(had_neg_percent, 1 / (np.array(had_means)**2 / had2_means), color = 'orange', marker = 'o', label = 'Hadronization β = 1 EMD', linestyle = '--')

plt.plot(hp_beta0p5_neg_percent, 1 / (np.array(hp_beta0p5_means)**2 / hp2_beta0p5_means), color = 'green', marker = 's', label = 'Hard Process β = 0.5 EMD', linestyle = '--')
plt.plot(sho_beta0p5_neg_percent, 1 / (np.array(sho_beta0p5_means)**2 / sho2_beta0p5_means), color = 'magenta', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')
plt.plot(had_beta0p5_neg_percent, 1 / (np.array(had_beta0p5_means)**2 / had2_beta0p5_means), color = 'lightsalmon', marker = 's', label = 'Showered β = 0.5 EMD', linestyle = '--')

plt.plot(hp_beta2_neg_percent, 1 / (np.array(hp_beta2_means)**2 / hp2_beta2_means), color = 'mediumslateblue', marker = '+', label = 'Hard Process β = 2 EMD', linestyle = '--')
plt.plot(sho_beta2_neg_percent, 1 / (np.array(sho_beta2_means)**2 / sho2_beta2_means), color = 'plum', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')
plt.plot(had_beta2_neg_percent, 1 / (np.array(had_beta2_means)**2 / had2_beta2_means), color = 'midnightblue', marker = '+', label = 'Showered β = 2 EMD', linestyle = '--')

plt.plot(hp_beta0_neg_percent, 1 / (np.array(hp_beta0_means)**2 / hp2_beta0_means), color = 'lime', marker = '*', label = 'Hard Process β = 0 EMD', linestyle = '--')
plt.plot(sho_beta0_neg_percent, 1 / (np.array(sho_beta0_means)**2 / sho2_beta0_means), color = 'mediumturquoise', marker = '*', label = 'Showered β = 0 EMD', linestyle = '--')
plt.plot(had_beta0_neg_percent, 1 / (np.array(had_beta0_means)**2 / had2_beta0_means), color = 'mediumpurple', marker = '*', label = 'Hadronization β = 0 EMD', linestyle = '--')

plt.plot(hp_betainf_neg_percent, 1 / (np.array(hp_betainf_means)**2 / hp2_betainf_means), color = 'purple', marker = 'x', label = 'Hard Process β = ∞ EMD', linestyle = '--')
plt.plot(sho_betainf_neg_percent, 1 / (np.array(sho_betainf_means)**2 / sho2_betainf_means), color = 'brown', marker = 'x', label = 'Showered β = ∞ EMD', linestyle = '--')
plt.plot(had_betainf_neg_percent, 1 / (np.array(had_betainf_means)**2 / had2_betainf_means), color = 'pink', marker = 'x', label = 'Hadronization β = ∞ EMD', linestyle = '--')

plt.plot(hp_p1semd_neg_percent, 1 / (np.array(hp_p1semd_means)**2 / hp2_p1semd_means), color = 'burlywood', marker = 'd', label = 'Hard Process p = 1 SEMD', linestyle = '--')
plt.plot(sho_p1semd_neg_percent, 1 / (np.array(sho_p1semd_means)**2 / sho2_p1semd_means), color = 'olive', marker = 'd', label = 'Showered p = 1 SEMD', linestyle = '--')
plt.plot(had_p1semd_neg_percent, 1 / (np.array(had_p1semd_means)**2 / had2_p1semd_means), color = 'turquoise', marker = 'd', label = 'Hadronization p = 1 SEMD', linestyle = '--')

plt.plot(hp_semd_neg_percent, 1 / (np.array(hp_semd_means)**2 / hp2_semd_means), color = 'cyan', marker = 'v', label = 'Hard Process p = 2 SEMD', linestyle = '--')

plt.axhline(1, color = 'black', linestyle = '--', label = 'Fully positive, uniform sample')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize = 12)
plt.xlim([0,1])
plt.xlabel('Reweighted Fraction', fontsize = 14)
plt.ylabel('Statistical Dilution', fontsize = 14)
plt.savefig('dilution.png', bbox_inches='tight')
